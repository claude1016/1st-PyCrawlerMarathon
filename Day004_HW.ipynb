# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
※post,get參考資料:https://blog.csdn.net/k_koris/article/details/82950654

# %%
'''
Your Code
'''
import requests 
import json
r=re.get('https://api.github.com/events')
print(r.text)

json.loads(r.text) #透過json轉化
# Out:
# [{"id":"11528831921","type":"PullRequestEvent","actor":{"id":181681,"login":"alikon","display_login":"alikon","gravatar_id":"","url":"https://api.github.com/users/alikon","avatar_url":"https://avatars.githubusercontent.com/u/181681?"},"repo":{"id":2464908,"name":"joomla/joomla-cms","url":"https://api.github.com/repos/joomla/joomla-cms"},"payload":{"action":"opened","number":27949,"pull_request":{"url":"https://api.github.com/repos/joomla/joomla-cms/pulls/27949","id":375804574,"node_id":"MDExOlB1bGxSZXF1ZXN0Mzc1ODA0NTc0","html_url":"https://github.com/joomla/joomla-cms/pull/27949","diff_url":"https://github.com/joomla/joomla-cms/pull/27949.diff","patch_url":"https://github.com/joomla/joomla-cms/pull/27949.patch","issue_url":"https://api.github.com/repos/joomla/joomla-cms/issues/27949","number":27949,"state":"open","locked":false,"title":"[3] fix wrong catid for contactcreator","user":{"login":"alikon","id":181681,"node_id":"MDQ6VXNlcjE4MTY4MQ==","avatar_url":"https://avatars0.githubus
# ...

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
r_1=re.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r_1.text
json.loads(r_1.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.25},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.28},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.21},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': 92.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H036',
# ...

# %%
r_2=re.get('https://cat-fact.herokuapp.com/facts')
json.loads(r_2.text)
# Out:
# {'all': [{'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
# ...
